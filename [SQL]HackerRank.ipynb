# %% [markdown]
# <a href="https://colab.research.google.com/github/cyberfury/Dataanalysis/blob/main/%5BSQL%5DHackerRank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The PADS
#
#
# ### ODRERY 에서 함수를 사용할 수 있음
# ### CONCAT , + 모두 사용가능
#
#
# ![image.png](data:image/png;base64,...)
